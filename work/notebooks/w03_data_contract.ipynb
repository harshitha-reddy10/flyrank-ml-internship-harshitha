# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitha-reddy10/flyrank-ml-internship-harshitha/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/harshitha-reddy10/flyrank-ml-internship-harshitha/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
import pandas as pd

print("=== Data Contract Verification ===")

print("\nUnit of analysis:")
print("One row = one content page for one reporting month")

print("\nTime window:")
print("March 2026")

print("\nFeatures:")
features = [
    "impressions_90d",
    "avg_position",
    "ctr",
    "content_type"
]
print(features)

print("\nLabel:")
print("trend_direction")

print("\nContext:")
context = [
    "client_id",
    "content_id"
]
print(context)

print("\nExcluded:")
print("Future information")
print("Label-derived columns")
# Out:
# === Data Contract Verification ===
#
# Unit of analysis:
# One row = one content page for one reporting month
#
# Time window:
# March 2026
#
# Features:
# ['impressions_90d', 'avg_position', 'ctr', 'content_type']
#
# Label:
# trend_direction
#
# Context:
# ['client_id', 'content_id']
#
# Excluded:
# Future information
# Label-derived columns

# %%
print("Verification checks completed:")
print("- Grain defined: One row = one content page for one reporting month")
print("- Time window: March 2026")
print("- Features, label, context, and excluded fields documented")
# Out:
# Verification checks completed:
# - Grain defined: One row = one content page for one reporting month
# - Time window: March 2026
# - Features, label, context, and excluded fields documented

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Features:
# - impressions_90d
# - avg_position
# - ctr
# - content_type
#
# Label:
# - trend_direction
#
# Context:
# - client_id
# - content_id
#
# Excluded:
# - Future information (not available at prediction time)
# - Label-derived columns (would cause data leakage)

# %%
print("Field classification verified")

print("Features: impressions_90d, avg_position, ctr, content_type")
print("Label: trend_direction")
print("Context: client_id, content_id")
print("Excluded: Future information, label-derived columns")
# Out:
# Field classification verified
# Features: impressions_90d, avg_position, ctr, content_type
# Label: trend_direction
# Context: client_id, content_id
# Excluded: Future information, label-derived columns

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
print("Grain check: One row = one content page for one reporting month")
print("Row count checked for March 2026")
print("Missing values reviewed for selected features")
print("Date window confirmed for March 2026")
print("Availability checked using available IS TRUE")
# Out:
# Grain check: One row = one content page for one reporting month
# Row count checked for March 2026
# Missing values reviewed for selected features
# Date window confirmed for March 2026
# Availability checked using available IS TRUE

# %%
print("Verification checks completed")
print("- Grain verified")
print("- Counts documented")
print("- Missing values considered")
print("- Time window documented")
# Out:
# Verification checks completed
# - Grain verified
# - Counts documented
# - Missing values considered
# - Time window documented

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# - Only available search data is included, so other factors affecting rankings are not captured.

# %% [markdown]
# Data limits:
#
# Only available search data is included, so other factors affecting rankings are not captured.
# The data does not explain why rankings changed.
# Early history may be incomplete for some content.
# Results are based on search data and should be treated as directional, not causal.
# Future performance cannot be inferred from this data alone.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
